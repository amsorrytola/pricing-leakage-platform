# %%
from normalized_table import normalized_table,normalized_table_groq

# %%
result = normalized_table_groq("Data/Axis_bank/Axis_COM_2025_001.md")
# Out:
# 📄 Processing contract: Axis_COM_2025_001.md
# 🔍 Retrieving pricing-related chunks...
# /home/chams/RAG_contract/vectorstore/chroma_store.py:9: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embedding_function=OllamaEmbeddings(model="nomic-embed-text")
# /home/chams/RAG_contract/vectorstore/chroma_store.py:7: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   return Chroma(
# ✅ Retrieved 6 pricing chunks
#
# 🧠 Extracting → Cash Management
# ✅ Cash Management extraction successful
#
# 🧠 Extracting → Domestic Payments
# ✅ Domestic Payments extraction successful
#
# 🧠 Extracting → International Payments
# ✅ International Payments extraction successful
#
# 🧠 Extracting → Trade Finance
# ✅ Trade Finance extraction successful
#
# 🧠 Extracting → Digital Services
# ✅ Digital Services extraction successful
#
# 🧠 Extracting → Credit Facilities
# ✅ Credit Facilities extraction successful
#
# 🧠 Extracting → Programs & Discounts
# ✅ Programs & Discounts extraction successful
#
# 🎉 All pricing extractions completed successfully

# %%
result
# Out:
# {'Cash Management': {'account_maintenance': {'price': 3500,
#    'unit': 'per_month',
#    'source_clause': 'SECTION 3 | Service | Fee | | | | | Account Maintenance (Monthly) | ₹3,500 |'},
#   'daily_statement_email': {'price': 250,
#    'unit': 'per_statement',
#    'source_clause': 'SECTION 3 | Service | Fee | | | | | Daily Statement (Email) | ₹250 per statement |'},
#   'monthly_reconciliation': {'price': 1200,
#    'unit': 'per_report',
#    'source_clause': 'SECTION 3 | Service | Fee | | | | | Monthly Reconciliation | ₹1,200 per report |'},
#   'custom_reports': {'price': 2000,
#    'unit': 'per_report',
#    'source_clause': 'SECTION 3 | Service | Fee | | | | | Custom MIS Reports | ₹2,000 per report |'}},
#  'Domestic Payments': {'ach_file': {'price': 650,
#    'unit': 'per_file',
#    'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | ACH File Origination | ₹650 per file |'},
#   'ach_transaction': {'price': 3.5,
#    'unit': 'per_transaction',
#    'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | ACH Transaction | ₹3.50 per transaction |'},
#   'rtgs': {'price': 75,
#    'unit': 'per_transaction',
#    'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | RTGS Transaction | ₹75 per transaction |'},
#   'neft': {'price': 35,
#    'unit': 'per_transaction',
#    'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | NEFT Transaction | ₹35 per transaction |'},
#   'cheque_processing': {'price': None,
#    'unit': 'per_cheque',
#    'source_clause': None},
#   'standing_instruction': {'setup_fee': {'price': 500,
#     'unit': 'one_time',
#     'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | Standing Instruction Setup | ₹500 (one time) |'},
#    'monthly_fee': {'price': 500,
#     'unit': 'per_month',
#     'source_clause': '3.3 Domestic Payment Processing Charges | Service | Fee | | | | | Standing Instruction Monthly | ₹500 per month |'}}},
#  'International Payments': {'swift_wire': {'price': 950,
#    'unit': 'per_transaction',
#    'source_clause': '3.4 International Payment Charges | Service | Fee | | | | | SWIFT Wire Transfer | ₹950 per transaction |'},
#   'fatca_screening': {'price': 100,
#    'unit': 'per_transaction',
#    'source_clause': '3.4 International Payment Charges | Service | Fee | | | | | FATCA Screening | ₹100 per transaction |'},
#   'correspondent_charges': {'handling_fee_percent': 8,
#    'unit': 'percentage_plus_actual',
#    'source_clause': '3.4 International Payment Charges | Service | Fee | | | | | Correspondent Charges | Actual + 8% handling |'},
#   'fx_markup': {'price': 0.75,
#    'unit': 'percentage',
#    'source_clause': '3.4 International Payment Charges | Service | Fee | | | | | FX Conversion | 0.75% markup on spot rate |'}},
#  'Trade Finance': {'lc_issuance': {'price': 16000,
#    'unit': 'per_lc',
#    'source_clause': 'For Crompton Greaves Consumer Electricals Limited, LC issuance fee REDUCED to ₹16,000 (from ₹18,000) for LCs exceeding ₹50 Lakhs'},
#   'lc_amendment': {'price': 6500,
#    'unit': 'per_amendment',
#    'source_clause': 'LC Amendment: If Crompton Greaves Consumer Electricals Limited requests LC amendment during validity (increasing amount, extending validity, modifying documents), Bank prepares amendment document and transmits via SWIFT MT707 to advising bank.'},
#   'lc_negotiation': {'price': 4500,
#    'unit': 'per_document_set',
#    'source_clause': 'When beneficiary presents documents under'},
#   'lc_discrepancy': {'price': 5000,
#    'unit': 'per_lc',
#    'source_clause': 'LC Discrepancy Handling: When beneficiary presents documents under'},
#   'bank_guarantee': {'price': 14500,
#    'unit': 'per_year',
#    'additional_year_price': 3000,
#    'source_clause': 'Bank Guarantee (1 year) | ₹14,500 | | Additional Guarantee Year | ₹3,000 per year'}},
#  'Digital Services': {'online_portal': {'price': 1500,
#    'unit': 'per_month',
#    'source_clause': 'Section 3.6 Digital Services Charges'},
#   'sweep_account': {'price': 3500,
#    'unit': 'per_month',
#    'source_clause': 'Section 3.6 Digital Services Charges'},
#   'api_setup': {'price': 35000,
#    'unit': 'one_time',
#    'source_clause': 'Section 3.6 Digital Services Charges'},
#   'api_transaction': {'price': 2.5,
#    'unit': 'per_transaction',
#    'source_clause': 'Section 3.6 Digital Services Charges'}},
#  'Credit Facilities': {'cash_credit': {'total_rate_percent_range': [10.5,
#     10.5],
#    'source_clause': 'Base Rate (8.00%) + Spread (2.50%) = 10.50% per annum'},
#   'trade_credit': {'total_rate_percent_range': [10.0, 10.0],
#    'source_clause': 'Base Rate (8.00%) + Spread (2.00%) = 10.00% per annum'},
#   'overdraft': {'total_rate_percent_range': [11.5, 11.5],
#    'source_clause': '11.50% per annum on daily overdrawn balance'}},
#  'Programs & Discounts': {'reduced_lc_fee': {'original_price': 18000,
#    'reduced_price': 16000,
#    'condition': 'LCs exceeding ₹50 Lakhs',
#    'source_clause': 'SECTION 3'},
#   'free_discrepancy_corrections': {'free_quantity': 2,
#    'unit': 'per calendar year',
#    'condition': 'null',
#    'source_clause': 'SECTION 3'},
#   'frozen_online_portal_fee': {'price': 1500,
#    'frozen': True,
#    'condition': 'null',
#    'source_clause': 'SECTION 3'},
#   'fixed_api_transaction_fee': {'price': 2.5,
#    'fixed': True,
#    'condition': 'null',
#    'source_clause': 'SECTION 3'}}}

# %%
catalog = {"cash_management": {
      "account_maintenance": {
        "service_code": "ACCT_MAINT",
        "unit": "per_month",
        "price": 2600,
        "escalation_applicable": 'truecash' 
      },
      "daily_statement_email": {
        "service_code": "DAILY_STMT_EMAIL",
        "unit": "per_statement",
        "price": 120
      },
      "monthly_reconciliation": {
        "service_code": "MONTHLY_RECON",
        "unit": "per_report",
        "price": 700
      },
      "custom_reports": {
        "service_code": "CUSTOM_REPORT",
        "unit": "per_report",
        "price": 1200
      }
    },

    "domestic_payments": {
      "ach_file": {
        "service_code": "ACH_FILE",
        "unit": "per_file",
        "price": 450
      },
      "ach_transaction": {
        "service_code": "ACH_TXN",
        "unit": "per_transaction",
        "price": 2.5
      },
      "rtgs": {
        "service_code": "RTGS",
        "unit": "per_transaction",
        "price": 45
      },
      "neft": {
        "service_code": "NEFT",
        "unit": "per_transaction",
        "price": 22
      },
      "cheque_processing": {
        "service_code": "CHEQUE",
        "unit": "per_cheque",
        "price": 30
      },
      "standing_instruction": {
        "setup_fee": {
          "unit": "one_time",
          "price": 300
        },
        "monthly_fee": {
          "unit": "per_month",
          "price": 300
        }
      }
    },

    "international_payments": {
      "swift_wire": {
        "service_code": "SWIFT",
        "unit": "per_transaction",
        "price": 800
      },
      "fatca_screening": {
        "service_code": "FATCA",
        "unit": "per_transaction",
        "price": 60
      },
      "correspondent_charges": {
        "service_code": "CORR_BANK",
        "unit": "percentage_plus_actual",
        "handling_fee_percent": 5.5
      },
      "fx_markup": {
        "service_code": "FX_MARKUP",
        "unit": "percentage",
        "price": 0.7
      }
    },

    "trade_finance": {
      "lc_issuance": {
        "service_code": "LC_ISSUE",
        "unit": "per_lc",
        "price": 13500
      },
      "lc_amendment": {
        "service_code": "LC_AMEND",
        "unit": "per_amendment",
        "price": 4500
      },
      "lc_negotiation": {
        "service_code": "LC_NEG",
        "unit": "per_document_set",
        "price": 3000
      },
      "lc_discrepancy": {
        "service_code": "LC_DISC",
        "unit": "per_lc",
        "price": 3500
      },
      "bank_guarantee": {
        "service_code": "BG",
        "unit": "per_year",
        "price": 11000,
        "additional_year_price": 2200
      }
    },

    "digital_services": {
      "online_portal": {
        "service_code": "PORTAL",
        "unit": "per_month",
        "price": 1000
      },
      "sweep_account": {
        "service_code": "SWEEP",
        "unit": "per_month",
        "price": 2500
      },
      "api_setup": {
        "service_code": "API_SETUP",
        "unit": "one_time",
        "price": 25000
      },
      "api_transaction": {
        "service_code": "API_TXN",
        "unit": "per_transaction",
        "price": 1.75
      }
    }}

# %%
from profiling import run_pricing_analysis

# %%
run_pricing_analysis(result,catalog)
# Out:
# ([{'category': 'Cash Management',
#    'service': 'account_maintenance',
#    'unit': 'per_month',
#    'catalog_price': 2600,
#    'contract_price': 3500,
#    'price_diff': 900,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Cash Management',
#    'service': 'daily_statement_email',
#    'unit': 'per_statement',
#    'catalog_price': 120,
#    'contract_price': 250,
#    'price_diff': 130,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Cash Management',
#    'service': 'monthly_reconciliation',
#    'unit': 'per_report',
#    'catalog_price': 700,
#    'contract_price': 1200,
#    'price_diff': 500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Cash Management',
#    'service': 'custom_reports',
#    'unit': 'per_report',
#    'catalog_price': 1200,
#    'contract_price': 2000,
#    'price_diff': 800,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'ach_file',
#    'unit': 'per_file',
#    'catalog_price': 450,
#    'contract_price': 650,
#    'price_diff': 200,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'ach_transaction',
#    'unit': 'per_transaction',
#    'catalog_price': 2.5,
#    'contract_price': 3.5,
#    'price_diff': 1.0,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'rtgs',
#    'unit': 'per_transaction',
#    'catalog_price': 45,
#    'contract_price': 75,
#    'price_diff': 30,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'neft',
#    'unit': 'per_transaction',
#    'catalog_price': 22,
#    'contract_price': 35,
#    'price_diff': 13,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'standing_instruction.setup_fee',
#    'unit': 'one_time',
#    'catalog_price': 300,
#    'contract_price': 500,
#    'price_diff': 200,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Domestic Payments',
#    'service': 'standing_instruction.monthly_fee',
#    'unit': 'per_month',
#    'catalog_price': 300,
#    'contract_price': 500,
#    'price_diff': 200,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'International Payments',
#    'service': 'swift_wire',
#    'unit': 'per_transaction',
#    'catalog_price': 800,
#    'contract_price': 950,
#    'price_diff': 150,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'International Payments',
#    'service': 'fatca_screening',
#    'unit': 'per_transaction',
#    'catalog_price': 60,
#    'contract_price': 100,
#    'price_diff': 40,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'International Payments',
#    'service': 'correspondent_charges.handling_fee_percent',
#    'unit': None,
#    'catalog_price': 5.5,
#    'contract_price': 8,
#    'price_diff': 2.5,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'International Payments',
#    'service': 'fx_markup',
#    'unit': 'percentage',
#    'catalog_price': 0.7,
#    'contract_price': 0.75,
#    'price_diff': 0.050000000000000044,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'PERCENTAGE'},
#   {'category': 'Trade Finance',
#    'service': 'lc_issuance',
#    'unit': 'per_lc',
#    'catalog_price': 13500,
#    'contract_price': 16000,
#    'price_diff': 2500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Trade Finance',
#    'service': 'lc_amendment',
#    'unit': 'per_amendment',
#    'catalog_price': 4500,
#    'contract_price': 6500,
#    'price_diff': 2000,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Trade Finance',
#    'service': 'lc_negotiation',
#    'unit': 'per_document_set',
#    'catalog_price': 3000,
#    'contract_price': 4500,
#    'price_diff': 1500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Trade Finance',
#    'service': 'lc_discrepancy',
#    'unit': 'per_lc',
#    'catalog_price': 3500,
#    'contract_price': 5000,
#    'price_diff': 1500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Trade Finance',
#    'service': 'bank_guarantee',
#    'unit': 'per_year',
#    'catalog_price': 11000,
#    'contract_price': 14500,
#    'price_diff': 3500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Digital Services',
#    'service': 'online_portal',
#    'unit': 'per_month',
#    'catalog_price': 1000,
#    'contract_price': 1500,
#    'price_diff': 500,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Digital Services',
#    'service': 'sweep_account',
#    'unit': 'per_month',
#    'catalog_price': 2500,
#    'contract_price': 3500,
#    'price_diff': 1000,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Digital Services',
#    'service': 'api_setup',
#    'unit': 'one_time',
#    'catalog_price': 25000,
#    'contract_price': 35000,
#    'price_diff': 10000,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'},
#   {'category': 'Digital Services',
#    'service': 'api_transaction',
#    'unit': 'per_transaction',
#    'catalog_price': 1.75,
#    'contract_price': 2.5,
#    'price_diff': 0.75,
#    'pricing_status': 'OVER_PRICED',
#    'pricing_type': 'ABSOLUTE'}],
#  0.471)

# %%
SUPABASE_URL=https://mzkwffsbsmbwqzmjhvwv.supabase.co
SUPABASE_SERVICE_ROLE_KEY=sb_secret_1iomz38JPxjgPWiJtDKHcA_I3fGDYbv
back
# Out:
#   Cell In[3], line 1
#     SUPABASE_URL=https://mzkwffsbsmbwqzmjhvwv.supabase.co
#                       ^
# SyntaxError: invalid syntax

# %%
NEXT_PUBLIC_API_BASE=http://127.0.0.1:8000
NEXT_PUBLIC_SUPABASE_URL=https://mzkwffsbsmbwqzmjhvwv.supabase.co
NEXT_PUBLIC_SUPABASE_ANON_KEY=sb_publishable_ANH_K6PaTBHHY_L9to9X7g_I8YgROAY
