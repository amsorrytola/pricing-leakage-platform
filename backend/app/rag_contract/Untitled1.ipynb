# %%
import json

# %%
from ingestion.md_loader import load_md

CONTRACT_PATH = "data/ZCB_COM_2025_004.md"

contract_text = load_md(CONTRACT_PATH)

print(contract_text[:600])
# Out:
# COMMERCIAL BANKING SERVICES AGREEMENT Agreement ID: ZCB/COM/2025/004 Effective Date: 2025 01 15 Duration: 3 years Bank: ZENITH COMMERCIAL BANK PLC, Mumbai, India Client: ConsumerGoods Trading Company Limited Client Registration: CIN: U51900GJ2016PTC083456 Principal Place of Business: Ahmedabad, Gujarat Relationship Manager: Neha Patel Contact Number: +91 79 4001 1000 1. INTRODUCTION AND PURPOSE 1.1 Scope of Services This Commercial Banking Services Agreement ("Agreement"), entered into as of 2025 01 15 ("Effective Date"), by and between ZENITH COMMERCIAL BANK PLC ("Bank"), a duly registered ba

# %%
from rag.retriever import retrieve_chunks

query = "pricing fees escalation minimum charges discounts"

docs = retrieve_chunks(query=query, k=8)

for i, doc in enumerate(docs):
    print(f"\n--- Retrieved Chunk {i+1} ---")
    print(doc.page_content[:400])
# Out:
# /home/chams/RAG_contract/embeddings/embedder.py:4: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   return OllamaEmbeddings(model="nomic-embed-text")
# /home/chams/RAG_contract/rag/retriever.py:9: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   db = Chroma(
# --- Retrieved Chunk 1 ---
# ...

# %%
context = "\n\n".join(doc.page_content for doc in docs)

print(context[:800])
# Out:
# in the invoice, the Client shall be liable to pay interest on the overdue amount at 12% per annum (calculated on simple interest basis) from the due date until the date of actual payment. Billing Disputes: Any discrepancies or disputes regarding fee invoices must be reported in writing to the Bank within 30 days of invoice date, with supporting documentation. Fee adjustments or reversals shall be processed within 10 business days of Bank's approval of the dispute claim. No interest accrues on disputed amounts pending resolution. 3.8 Annual Fee Escalation {escalation clause} 3.9 Minimum Activity Requirement {minimum activity fee clause} 3.10 Volume Based Discounts and Performance Incentives {volume discount clause} 4. CREDIT FACILITIES AND COLLATERAL 4.1 Cash Credit Facility Facility
#
# appro

# %%
from rag.extractor import detect_revenue_leakage

ai_output = detect_revenue_leakage()

print(json.dumps(json.loads(ai_output), indent=2))
